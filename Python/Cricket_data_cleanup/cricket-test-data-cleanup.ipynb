# %%
#import pandas as pd

# %%
import pandas as pd

# %%
#import csv

# %%
df = pd.read_csv('criket_data.csv')
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 61   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 62  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 63  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 64    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 65   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %%
#rename multiple columns in a list

# %%
df = df.rename(columns = {'Mat':'Matches', 'NO':'Not_Out', 'HS':'Highest_Inns_Score', 'BF':'Balls_Faced', 'SR':'Batting_Strike_Rate'})

# %%
df.head()
# Out:
#              Player       Span  Matches  Inns  Not_Out  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52    80       10  6996
# 1    HC Brook (ENG)  2022-2023       12    20        1  1181
# 2    AC Voges (AUS)  2015-2016       20    31        7  1485
# 3   RG Pollock (SA)  1963-1970       23    41        4  2256
# 4   GA Headley (WI)  1930-1954       22    40        4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 0                334  99.94       9800+                58.60   29  13  7
# 1                186  62.15        1287                91.76    4   7  1
# 2               269*  61.87        2667                55.68    5   4  2
# 3                274  60.97       1707+                54.48    7  11  1
# 4               270*  60.83        416+                56.00   10   5  2
#
#      4s  6s
# 0  626+   6
# 1   141  23
# 2   186   5
# 3  246+  11
# 4  104+   1

# %%
#check null values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Out                False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna() == 1]  #retrieving all records with Balls_Faced column null
# Out:
#                   Player       Span  Matches  Inns  Not_Out  Runs  \
# 9         ED Weekes (WI)  1948-1958       48    81        5  4455
# 17       CL Walcott (WI)  1948-1960       44    74        7  3798
# 58  Hon.FS Jackson (ENG)  1893-1905       20    33        4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 9                 207  58.61         NaN                  NaN   15  19  6
# 17                220  56.68         NaN                  NaN   15  14  1
# 58               144*  48.79         NaN                  NaN    5   6  3
#
#       4s  6s
# 9   258+   2
# 17  107+  11
# 58   51+   0

# %%
#Fill null values

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)

# %%
#Check if null values have been filled

# %%
df[df['Player'] == 'Hon.FS Jackson (ENG)']
# Out:
#                   Player       Span  Matches  Inns  Not_Out  Runs  \
# 58  Hon.FS Jackson (ENG)  1893-1905       20    33        4  1415
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 58               144*  48.79           0                  0.0    5   6  3
#
#      4s 6s
# 58  51+  0

# %%
#drop dupliccates

# %%
df.duplicated() #Check duplicates
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
df[df['Player'].duplicated() == 1] #Retrieve duplicated records
# Out:
#              Player       Span  Matches  Inns  Not_Out  Runs  \
# 5   GA Headley (WI)  1930-1954       22    40        4  2190
# 13   GS Sobers (WI)  1954-1974       93   160       21  8032
# 16   JB Hobbs (ENG)  1908-1930       61   102        7  5410
# 54    V Kohli (IND)  2011-2024      113   191       11  8848
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 5                270*  60.83        416+                56.00   10   5   2
# 13               365*  57.78       4063+                53.58   26  30  12
# 16                211  56.94       5363+                46.22   15  28   4
# 54               254*  49.15       15924                55.56   29  30  14
#
#       4s   6s
# 5   104+    1
# 13  593+  32+
# 16  276+    8
# 54   991   26

# %%
df[df['Player'].isin(['GA Headley (WI)', 'GS Sobers (WI)', 'JB Hobbs (ENG)', 'V Kohli (IND)'])] #Retrieve all duplicated records
# Out:
#              Player       Span  Matches  Inns  Not_Out  Runs  \
# 4   GA Headley (WI)  1930-1954       22    40        4  2190
# 5   GA Headley (WI)  1930-1954       22    40        4  2190
# 12   GS Sobers (WI)  1954-1974       93   160       21  8032
# 13   GS Sobers (WI)  1954-1974       93   160       21  8032
# 15   JB Hobbs (ENG)  1908-1930       61   102        7  5410
# 16   JB Hobbs (ENG)  1908-1930       61   102        7  5410
# 53    V Kohli (IND)  2011-2024      113   191       11  8848
# 54    V Kohli (IND)  2011-2024      113   191       11  8848
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 4                270*  60.83        416+                56.00   10   5   2
# 5                270*  60.83        416+                56.00   10   5   2
# 12               365*  57.78       4063+                53.58   26  30  12
# 13               365*  57.78       4063+                53.58   26  30  12
# ...

# %%
df.drop_duplicates()
# Out:
#                Player       Span  Matches  Inns  Not_Out  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80       10  6996
# 1      HC Brook (ENG)  2022-2023       12    20        1  1181
# 2      AC Voges (AUS)  2015-2016       20    31        7  1485
# 3     RG Pollock (SA)  1963-1970       23    41        4  2256
# 4     GA Headley (WI)  1930-1954       22    40        4  2190
# ..                ...        ...      ...   ...      ...   ...
# 61   KD Walters (AUS)  1965-1981       74   125       14  5357
# 62  GC Smith (ICC/SA)  2002-2014      117   205       13  9265
# 63  WH Ponsford (AUS)  1924-1934       29    48        4  2122
# 64    SJ McCabe (AUS)  1930-1938       39    62        5  2748
# 65   DR Jardine (ENG)  1928-1934       22    33        6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
df = df.drop_duplicates() # Assign to original dataframe

# %%
df[df['Player'].isin(['GA Headley (WI)', 'GS Sobers (WI)', 'JB Hobbs (ENG)', 'V Kohli (IND)'])] #Confirm duplicates has been dropped
# Out:
#              Player       Span  Matches  Inns  Not_Out  Runs  \
# 4   GA Headley (WI)  1930-1954       22    40        4  2190
# 12   GS Sobers (WI)  1954-1974       93   160       21  8032
# 15   JB Hobbs (ENG)  1908-1930       61   102        7  5410
# 53    V Kohli (IND)  2011-2024      113   191       11  8848
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 4                270*  60.83        416+                56.00   10   5   2
# 12               365*  57.78       4063+                53.58   26  30  12
# 15                211  56.94       5363+                46.22   15  28   4
# 53               254*  49.15       15924                55.56   29  30  14
#
#       4s   6s
# 4   104+    1
# 12  593+  32+
# 15  276+    8
# 53   991   26

# %%
# Split up Span into Start and End Date

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final_Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Out  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80       10  6996
# 1      HC Brook (ENG)  2022-2023       12    20        1  1181
# 2      AC Voges (AUS)  2015-2016       20    31        7  1485
# 3     RG Pollock (SA)  1963-1970       23    41        4  2256
# 4     GA Headley (WI)  1930-1954       22    40        4  2190
# ..                ...        ...      ...   ...      ...   ...
# 61   KD Walters (AUS)  1965-1981       74   125       14  5357
# 62  GC Smith (ICC/SA)  2002-2014      117   205       13  9265
# 63  WH Ponsford (AUS)  1924-1934       29    48        4  2122
# 64    SJ McCabe (AUS)  1930-1938       39    62        5  2748
# 65   DR Jardine (ENG)  1928-1934       22    33        6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
# Drop Span column

# %%
df.drop(['Span'], axis = 1) #axis is = 1 because we want to drop the column
# Out:
#                Player  Matches  Inns  Not_Out  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman (AUS)       52    80       10  6996                334  99.94
# 1      HC Brook (ENG)       12    20        1  1181                186  62.15
# 2      AC Voges (AUS)       20    31        7  1485               269*  61.87
# 3     RG Pollock (SA)       23    41        4  2256                274  60.97
# 4     GA Headley (WI)       22    40        4  2190               270*  60.83
# ..                ...      ...   ...      ...   ...                ...    ...
# 61   KD Walters (AUS)       74   125       14  5357                250  48.26
# 62  GC Smith (ICC/SA)      117   205       13  9265                277  48.25
# 63  WH Ponsford (AUS)       29    48        4  2122                266  48.22
# 64    SJ McCabe (AUS)       39    62        5  2748                232  48.21
# 65   DR Jardine (ENG)       22    33        6  1296                127  48.00
#
# ...

# %%
df = df.drop(['Span'], axis = 1) # Asign to original dataframe

# %%
# Split up the country from the player

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 4       [GA Headley , WI)]
#               ...
# 61     [KD Walters , AUS)]
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 64      [SJ McCabe , AUS)]
# 65     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Country'] = df['Country'].str.split(pat = ')').str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1        ENG
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 61       AUS
# 62    ICC/SA
# 63       AUS
# 64       AUS
# 65       ENG
# Name: Country, Length: 62, dtype: object

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df.head()
# Out:
#         Player  Matches  Inns  Not_Out  Runs Highest_Inns_Score    Ave  \
# 0  DG Bradman        52    80       10  6996                334  99.94
# 1    HC Brook        12    20        1  1181                186  62.15
# 2    AC Voges        20    31        7  1485               269*  61.87
# 3  RG Pollock        23    41        4  2256                274  60.97
# 4  GA Headley        22    40        4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626+   6        1928
# 1        1287                91.76    4   7  1   141  23        2022
# 2        2667                55.68    5   4  2   186   5        2015
# 3       1707+                54.48    7  11  1  246+  11        1963
# 4        416+                56.00   10   5  2  104+   1        1930
#
#   Final_Year Country
# 0       1948     AUS
# 1       2023     ENG
# 2       2016     AUS
# 3       1970      SA
# ...

# %%
# Change data types

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score'].str.split(pat = '*').str[0]
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 61    250
# 62    277
# 63    266
# 64    232
# 65    127
# Name: Highest_Inns_Score, Length: 62, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*').str[0]

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Rookie_Year'] = df['Rookie_Year'].astype('int')

# %%
df['Final_Year'] = df['Final_Year'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['4s'] = df['4s'].str.split(pat = '+').str[0]

# %%
df['6s'] = df['6s'].str.split(pat = '+').str[0]

# %%
df = df.astype({'4s':'int', '6s':'int'})

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df.head()
# Out:
#         Player  Matches  Inns  Not_Out  Runs  Highest_Inns_Score    Ave  \
# 0  DG Bradman        52    80       10  6996                 334  99.94
# 1    HC Brook        12    20        1  1181                 186  62.15
# 2    AC Voges        20    31        7  1485                 269  61.87
# 3  RG Pollock        23    41        4  2256                 274  60.97
# 4  GA Headley        22    40        4  2190                 270  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 0       9800+                58.60   29  13  7  626   6         1928
# 1        1287                91.76    4   7  1  141  23         2022
# 2        2667                55.68    5   4  2  186   5         2015
# 3       1707+                54.48    7  11  1  246  11         1963
# 4        416+                56.00   10   5  2  104   1         1930
#
#    Final_Year Country
# 0        1948     AUS
# 1        2023     ENG
# 2        2016     AUS
# 3        1970      SA
# ...

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df[df['Balls_Faced'].isna() == 1]
# Out:
#              Player  Matches  Inns  Not_Out  Runs  Highest_Inns_Score    Ave  \
# 9        ED Weekes        48    81        5  4455                 207  58.61
# 17      CL Walcott        44    74        7  3798                 220  56.68
# 58  Hon.FS Jackson        20    33        4  1415                 144  48.79
#
#    Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 9          NaN                  0.0   15  19  6  258   2         1948
# 17         NaN                  0.0   15  14  1  107  11         1948
# 58         NaN                  0.0    5   6  3   51   0         1893
#
#     Final_Year Country
# 9         1958      WI
# 17        1960      WI
# 58        1905     ENG

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df[df['Balls_Faced'].isna() == 1]
# Out:
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Out, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Rookie_Year, Final_Year, Country]
# Index: []

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
# Find career_length

# %%
df['career_length'] = df['Final_Year'] - df['Rookie_Year']

# %%
df
# Out:
#           Player  Matches  Inns  Not_Out  Runs  Highest_Inns_Score    Ave  \
# 0    DG Bradman        52    80       10  6996                 334  99.94
# 1      HC Brook        12    20        1  1181                 186  62.15
# 2      AC Voges        20    31        7  1485                 269  61.87
# 3    RG Pollock        23    41        4  2256                 274  60.97
# 4    GA Headley        22    40        4  2190                 270  60.83
# ..           ...      ...   ...      ...   ...                 ...    ...
# 61   KD Walters        74   125       14  5357                 250  48.26
# 62     GC Smith       117   205       13  9265                 277  48.25
# 63  WH Ponsford        29    48        4  2122                 266  48.22
# 64    SJ McCabe        39    62        5  2748                 232  48.21
# 65   DR Jardine        22    33        6  1296                 127  48.00
#
#     Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s  Rookie_Year  \
# ...

# %%
## Calculations

# %%
# What is the Average Career_Lenght

# %%
df['career_length'].mean()
# Out:
# 13.161290322580646

# %%
# AVG Batting_Strike_Rate for cricketers who played over 10 years

# %%
df[df['career_length'] > 10]['Batting_Strike_Rate'].mean()
# Out:
# 47.95477272727273

# %%
# Find number of cricketers who played before 1960

# %%
df[df['Rookie_Year'] < 1960]['Player'].count()
# Out:
# 23

# %%
# Max Highest_Inns_Score by country

# %%
df.groupby('Country')['Highest_Inns_Score'].max().to_frame('Highincountry').reset_index().sort_values('Highincountry', ascending = False)
# Out:
#     Country  Highincountry
# 5    ICC/WI            400
# 0       AUS            380
# 10       SL            374
# 11       WI            365
# 1       ENG            364
# 3   ICC/PAK            329
# 2   ICC/IND            319
# 8       PAK            313
# 9        SA            278
# 4    ICC/SA            277
# 6       IND            254
# 7        NZ            251
# 12      ZIM            232

# %%
# Hundreds, Fifties, ducks (0) AVG by country

# %%
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.312500   8.500000
# ENG      12.307692  20.769231   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       17.000000  21.000000   5.500000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
